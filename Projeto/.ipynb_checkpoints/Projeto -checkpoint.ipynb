# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # A análise:
#
# DataSet: https://www.kaggle.com/undp/human-development
#
# The object of this project is to develop a Machine Learning model capable of predicting the HDI (Human Developmente Index) with the support of multiple parameters, such as life expectancy and poverty rates.
#
# Variável Dependente: HDI (Human Development Index)
#
# Variável Independente:

# %%
HDI = pd.read_csv('human_development.csv')
POV = pd.read_csv('multidimensional_poverty.csv')
INE = pd.read_csv('inequality_adjusted.csv')
GEN_INE = pd.read_csv('gender_inequality.csv')
GEN_DEV = pd.read_csv('gender_development.csv')

HDI.tail(15)
# Out:
#      HDI Rank                          Country  Human Development Index (HDI)  \
# 180     181.0                     Sierra Leone                          0.413
# 181     182.0                           Guinea                          0.411
# 182     183.0                     Burkina Faso                          0.402
# 183     184.0                          Burundi                          0.400
# 184     185.0                             Chad                          0.392
# 185     186.0                          Eritrea                          0.391
# 186     187.0         Central African Republic                          0.350
# 187     188.0                            Niger                          0.348
# 188       NaN                      Arab States                          0.686
# 189       NaN        East Asia and the Pacific                          0.710
# 190       NaN          Europe and Central Asia                          0.748
# ...
